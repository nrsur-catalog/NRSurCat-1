# %% [markdown]
# <a href="https://colab.research.google.com/github/cjhaster/NRSurrogateCatalog/blob/gh-pages/_sources/events/GW191222_033537.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd

pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
import pip

try:
    __import__("nrsur_catalog")
except ImportError:
    pip.main(
        [
            "install",
            "nrsur_catalog @ git+https://github.com/cjhaster/NRSurrogateCatalog@main#egg",
            "-q",
        ]
    )

# %% [markdown]
# # GW191222_033537
#
# Below are some plots for GW191222_033537 from the NRSurrogate Catalog.

# %%
from nrsur_catalog import NRsurResult

nrsur_result = NRsurResult.load("GW191222_033537", cache_dir=".nrsur_catalog_cache")
# you can specify a `cache_dir`: folder where data will be downloaded

# %% [markdown]
# ## Summary

# %%
nrsur_result.summary()
# Out:
#                                                Posterior 90% CI  \
# Parameter
# $m_1\ [M_{\odot}]$                    ${66.48}_{-6.29}^{+8.29}$
# $m_2\ [M_{\odot}]$                    ${51.57}_{-8.32}^{+6.24}$
# $\mathcal{M}\ [M_{\odot}]$            ${50.37}_{-3.61}^{+3.74}$
# $q$                                    ${0.79}_{-0.19}^{+0.14}$
# $a_1$                                  ${0.36}_{-0.25}^{+0.36}$
# $a_2$                                  ${0.41}_{-0.28}^{+0.35}$
# $\theta_1$                             ${1.74}_{-0.64}^{+0.60}$
# $\theta_2$                             ${1.71}_{-0.68}^{+0.64}$
# $\chi_{\mathrm{eff}}$                 ${-0.05}_{-0.13}^{+0.11}$
# $\chi_{\mathrm{p}}$                    ${0.40}_{-0.22}^{+0.28}$
# $\alpha$                               ${3.62}_{-2.16}^{+0.88}$
# $\delta$                              ${-0.64}_{-0.50}^{+1.15}$
# $t_c\ [s]$                    ${1261020955.10}_{-0.00}^{+0.03}$
# ...

# %% [markdown]
# | Parameter                    | Posterior 90% CI                  | Prior                                           |
# |:-----------------------------|:----------------------------------|:------------------------------------------------|
# | $m_1\ [M_{\odot}]$           | ${66.48}_{-6.29}^{+8.29}$         | $-$                                             |
# | $m_2\ [M_{\odot}]$           | ${51.57}_{-8.32}^{+6.24}$         | $-$                                             |
# | $\mathcal{M}\ [M_{\odot}]$   | ${50.37}_{-3.61}^{+3.74}$         | $\text{UniformInComponentsChirpMass} [12, 400]$ |
# | $q$                          | ${0.79}_{-0.19}^{+0.14}$          | $\text{UniformInComponentsMassRatio} [0.17, 1]$ |
# | $a_1$                        | ${0.36}_{-0.25}^{+0.36}$          | $\text{Uniform} [0, 0.99]$                      |
# | $a_2$                        | ${0.41}_{-0.28}^{+0.35}$          | $\text{Uniform} [0, 0.99]$                      |
# | $\theta_1$                   | ${1.74}_{-0.64}^{+0.60}$          | $\text{Sine} [0, 3.14]$                         |
# | $\theta_2$                   | ${1.71}_{-0.68}^{+0.64}$          | $\text{Sine} [0, 3.14]$                         |
# | $\chi_{\mathrm{eff}}$        | ${-0.05}_{-0.13}^{+0.11}$         | $-$                                             |
# | $\chi_{\mathrm{p}}$          | ${0.40}_{-0.22}^{+0.28}$          | $-$                                             |
# | $\alpha$                     | ${3.62}_{-2.16}^{+0.88}$          | $-$                                             |
# | $\delta$                     | ${-0.64}_{-0.50}^{+1.15}$         | $-$                                             |
# | $t_c\ [s]$                   | ${1261020955.10}_{-0.00}^{+0.03}$ | $\text{Uniform} [1261020955.02, 1261020955.22]$ |
# | $d_L\ [Mpc]$                 | ${2846.01}_{-1051.42}^{+1121.66}$ | $\text{UniformSourceFrame} [100.0, 10000.0]$    |
# | $\phi$                       | ${3.41}_{-2.25}^{+1.87}$          | $\text{Uniform} [0, 6.28]$                      |
# | $\phi$                       | ${2.32}_{-0.71}^{+2.57}$          | $\text{Uniform} [0, 6.28]$                      |
# | $\theta$                     | ${1.71}_{-0.05}^{+0.05}$          | $\text{Sine} [0, 3.14]$                         |
# | $\psi$                       | ${1.22}_{-0.84}^{+1.45}$          | $\text{Uniform} [0, 3.14]$                      |
# | $\phi_{\mathrm{JL}}$         | ${3.11}_{-2.04}^{+2.12}$          | $\text{Uniform} [0, 6.28]$                      |
# | $\phi_{12}$                  | ${3.13}_{-2.07}^{+2.08}$          | $\text{Uniform} [0, 6.28]$                      |
# | $\theta_{\mathrm{JN}}$       | ${1.68}_{-1.13}^{+0.95}$          | $\text{Sine} [0, 3.14]$                         |
# | $m_f\ [M_{\odot}]$           | ${112.33}_{-6.90}^{+7.59}$        | $-$                                             |
# | $\chi_f$                     | ${0.67}_{-0.05}^{+0.04}$          | $-$                                             |
# | $v_{\rm kick}\ [{\rm km/s}]$ | ${435.99}_{-267.99}^{+578.69}$    | $-$                                             |

# %% [markdown]
# Lets make some plots!

# %%
# NRSurrogate corner plots

import os

param_sets = dict(
    mass=["mass_1", "mass_2", "chirp_mass", "mass_ratio"],
    spin=["a_1", "a_2", "tilt_1", "tilt_2"],
    effective_spin=["mass_ratio", "chi_eff", "chi_p"],
    sky_localisation=["luminosity_distance", "ra", "dec"],
    remnant=["final_mass", "final_spin", "final_kick"],
)
for name, params in param_sets.items():
    fname = f"GW191222_033537_{name}_corner.png"
    if not os.path.isfile(fname):
        fig = nrsur_result.plot_corner(params)
        fig.savefig(fname)

    if name == "remnant":
        continue

    # LVK-Comparison plots
    fname = f"GW191222_033537_compare_{name}_corner.png"
    if not os.path.isfile(fname):
        fig = nrsur_result.plot_lvk_comparison_corner(params)
        fig.savefig(fname)

# %% [markdown]
# ## Corner Plots
#
# ### Mass
#
#
# ::::{tab-set}
#
# :::{tab-item} NRSurrogate
# :sync: key1
#
# !["GW191222_033537_mass_corner.png"](GW191222_033537_mass_corner.png)
# :::
#
# :::{tab-item} LVK-Comparison
# :sync: key2
#
# !["GW191222_033537_compare_mass_corner.png"](GW191222_033537_compare_mass_corner.png)
# :::
#
# ::::
#
#
#
# ### Spin
#
#
# ::::{tab-set}
#
# :::{tab-item} NRSurrogate
# :sync: key1
#
# !["GW191222_033537_spin_corner.png"](GW191222_033537_spin_corner.png)
# :::
#
# :::{tab-item} LVK-Comparison
# :sync: key2
#
# !["GW191222_033537_compare_spin_corner.png"](GW191222_033537_compare_spin_corner.png)
# :::
#
# ::::
#
#
# ### Effective Spin
#
#
# ::::{tab-set}
#
# :::{tab-item} NRSurrogate
# :sync: key1
#
# !["GW191222_033537_effective_spin_corner.png"](GW191222_033537_effective_spin_corner.png)
# :::
#
# :::{tab-item} LVK-Comparison
# :sync: key2
#
# !["GW191222_033537_compare_effective_spin_corner.png"](GW191222_033537_compare_effective_spin_corner.png)
# :::
#
# ::::
#
#
#
# ### Sky-localisation
#
#
# ::::{tab-set}
#
# :::{tab-item} NRSurrogate
# :sync: key1
#
# !["GW191222_033537_sky_localisation_corner.png"](GW191222_033537_sky_localisation_corner.png)
# :::
#
# :::{tab-item} LVK-Comparison
# :sync: key2
#
# !["GW191222_033537_compare_sky_localisation_corner.png"](GW191222_033537_compare_sky_localisation_corner.png)
# :::
#
# ::::
#
#
#
# ### Remnant
#
# !["GW191222_033537_remnant_corner.png"](GW191222_033537_remnant_corner.png)

# %% [markdown]
# ## Waveform posterior-predictive plot

# %%
fname = f"GW191222_033537_waveform.png"
if not os.path.isfile(fname):
    fig = nrsur_result.plot_signal(outdir=".")

# %% [markdown]
# ![waveform](GW191222_033537_waveform.png)

# %% [markdown]
# ## Animations
# Here are some animations of the posterior.
#
# |Spin       |
# |-----------|
# | <iframe width="560" height="315" src="https://www.youtube.com/embed/msRN00Spjbs?loop=1" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>    |
#
# |Remnant       |
# |-----------|
# | <iframe width="560" height="315" src="https://www.youtube.com/embed/mkxggi9SM8M?loop=1" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>    |

# %% [markdown]
# ## Analysis configs
# Below are the configs used for the analysis of this job.

# %%
nrsur_result.print_configs()
# Out:
# Tmax:                               10000
# accounting:                         None
# accounting_user:                    None
# adapt:                              False
# allow_tape:                         True
# analysis_executable:                None
# analysis_executable_parser:         None
# autocorr_c:                         5.0
# autocorr_tol:                       50.0
# bilby_zero_likelihood_mode:         False
# burn_in_nact:                       50.0
# calibration_model:                  CubicSpline
# calibration_prior_boundary:         reflective
# catch_waveform_errors:              True
# channel_dict:                       {H1:DCS-CALIB_STRAIN_CLEAN_SUB60HZ_C01, L1:DCS-CALIB_STRAIN_CLEAN_SUB60HZ_C01}
# check_point_deltaT:                 3600
# clean:                              False
# coherence_test:                     False
# conda_env:                          None
# condor_job_priority:                0
# conversion_function:                None
# ...

# %% [markdown]
# If you used this data, please [cite this work](../citation.md).
