# %% [markdown]
# # Catalog plots
#
# Here we have some catalog plots showing the ensemble results of the catalog

# %%
from nrsur_catalog import Catalog

catalog = Catalog.load()
# Out:
# |NURSUR CATALOG|02/03 23:28:14|WARNING| Overwriting cache dir /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache with ../../../../tests/test_events_dir
# |NURSUR CATALOG|02/03 23:28:14|INFO| Setting cache dir to: ../../../../tests/test_events_dir
# Loading events:   0%|          | 0/10 [00:00<?, ?it/s]
# |NURSUR CATALOG|02/03 23:28:14|WARNING| Overwriting cache dir ../../../../tests/test_events_dir with /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:14|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:14|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:15|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:15|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:15|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:15|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:15|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:15|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:15|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache
# |NURSUR CATALOG|02/03 23:28:15|INFO| Setting cache dir to: /Users/avaj0001/Documents/projects/nrsurrogate_catalog/src/nrsur_catalog/web_builder/page_templates/.nrsur_catalog_cache

# %%
catalog.violin_plot('mass_1');

# %%
catalog.violin_plot('chi_eff');
